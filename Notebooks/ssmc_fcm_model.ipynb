# %%
# !git clone https://megaheart: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@github.com/megaheart/Multiple_Fuzzification_Coefficients_FCM.git
# Out:
# Cloning into 'Multiple_Fuzzification_Coefficients_FCM'...
# remote: Enumerating objects: 101, done.
# remote: Counting objects: 100% (101/101), done.
# remote: Compressing objects: 100% (68/68), done.
# remote: Total 101 (delta 33), reused 96 (delta 28), pack-reused 0
# Receiving objects: 100% (101/101), 6.42 MiB | 9.00 MiB/s, done.
# Resolving deltas: 100% (33/33), done.

# %%
# !git clone https://megaheart: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@github.com/megaheart/Multiple_Fuzzification_Coefficients_FCM.git
# Out:
# fatal: destination path 'Multiple_Fuzzification_Coefficients_FCM' already exists and is not an empty directory.

# %%
# !pip install scipy
# Out:
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (1.11.4)
# Requirement already satisfied: numpy<1.28.0,>=1.21.6 in /usr/local/lib/python3.10/dist-packages (from scipy) (1.25.2)

# %%
import numpy as np
import matplotlib.pyplot as plt
import sklearn.preprocessing as pre
import pandas as pd
from sklearn.model_selection import train_test_split, KFold
from sklearn.metrics import mean_squared_error, accuracy_score
from sklearn.preprocessing import MinMaxScaler
import math, time
import os
import sys

sys.path.append(os.path.join(os.path.abspath(''), 'Multiple_Fuzzification_Coefficients_FCM/'))

# %%
os.path.join(os.path.abspath(''), 'Multiple_Fuzzification_Coefficients_FCM/')

# %%
from Components.Algorithms.sSMC_FCM import sSMC_FCM
import Components.Cores.clusters_generations as cg

# %%
C = 10
RANGE_COUNT = 1000
# ### Load the data
data_path = "./Multiple_Fuzzification_Coefficients_FCM/Data/battery_cycles.csv"
dataframe = pd.read_csv(data_path)

# Split train and test
test_battery_orders = [82, 16, 4, 96, 36, 32, 29, 18, 14]
print(test_battery_orders)

terribled_battery_orders = [15, 51, 117, 118, 119, 120]

train_battery_orders = [i for i in range(1, 125) if i not in test_battery_orders and i not in terribled_battery_orders]

train_X = dataframe[dataframe['battery_order'].isin(train_battery_orders)]\
    [["c1a_I_dt", "c1a_avg_T", "c1a_avg_I", "c1_max_I","c2_max_I", "c1_max_T", "c1_min_T", "c2_max_T", "c2_min_T"]]\
    .to_numpy()
train_Qi = dataframe[dataframe['battery_order'].isin(train_battery_orders)][["Qi"]]\
    .to_numpy()
test_X = dataframe[dataframe['battery_order'].isin(test_battery_orders)]\
    [["c1a_I_dt", "c1a_avg_T", "c1a_avg_I", "c1_max_I","c2_max_I", "c1_max_T", "c1_min_T", "c2_max_T", "c2_min_T"]]\
    .to_numpy()
test_Qi = dataframe[dataframe['battery_order'].isin(test_battery_orders)][["Qi"]]\
    .to_numpy()

battery_cycles_count = [len(dataframe[dataframe['battery_order'] == i]) for i in range(1, 125)]
print(battery_cycles_count)
print(np.sum(battery_cycles_count))

train_size, test_size = len(train_X), len(test_X)

scaler = MinMaxScaler()
train_X = scaler.fit_transform(train_X)
test_X = scaler.transform(test_X)
X = np.concatenate((train_X, test_X), axis=0)
N = len(X)
Y = np.full(N, np.nan)
elements_Qi = np.concatenate((train_Qi, test_Qi), axis=0)
# Out:
# [82, 16, 4, 96, 36, 32, 29, 18, 14]
# [1850, 2158, 2235, 1432, 1571, 1072, 634, 868, 1052, 786, 878, 717, 860, 855, 689, 786, 532, 557, 1012, 1015, 852, 868, 840, 857, 915, 706, 874, 729, 755, 740, 700, 702, 646, 615, 623, 964, 1049, 700, 649, 613, 596, 249, 149, 438, 335, 444, 480, 512, 561, 477, 459, 483, 485, 494, 487, 462, 502, 489, 513, 528, 496, 461, 472, 469, 512, 498, 481, 493, 519, 521, 500, 464, 535, 479, 465, 459, 498, 430, 466, 462, 458, 486, 431, 713, 489, 499, 509, 450, 429, 402, 796, 934, 807, 513, 465, 484, 475, 461, 411, 480, 476, 455, 399, 503, 414, 530, 506, 464, 489, 450, 464, 425, 440, 823, 1143, 1189, 423, 280, 434, 459, 457, 494, 1015, 509]
# 79712

# %%
# Quantiles the Qi
i_Qi = np.argsort(train_Qi, axis=0)
clusters_Qi = np.zeros(C)

idx_start = 0
avg_size = len(train_Qi) // C
for i in range(C):
    idx_end = i * avg_size + avg_size
    if i == C - 1:
        idx_end = len(train_Qi)
    Y[i_Qi[idx_start:idx_end]] = i
    clusters_Qi[i] = np.mean(train_Qi[i_Qi[idx_start:idx_end]])
    idx_start = idx_end

for i in range(C):
    if np.any(Y == i):
        continue
    else:
        print(f"Cluster {i} don't have any elements")

# %%
test_Y = np.full(test_size, np.nan)
for i in range(train_size, N):
    d = np.abs(clusters_Qi - elements_Qi[i])
    cluster_idx = np.argmin(d)
    test_Y[i - train_size] = cluster_idx

# %%
clusters_Qi
# Out:
# array([0.91923775, 0.98313989, 1.02073743, 1.04118805, 1.05438203,
#        1.06420122, 1.07139336, 1.07713925, 1.0835411 , 1.09989421])

# %%
# "c1a_I_dt", "c1a_avg_T", "c1a_avg_I", "c1_max_I", "c2_max_I",
# "c1_max_T", "c1_min_T", "c2_max_T", "c2_min_T"
# alpha_fea = np.array([0.45, 0.225, 0.225, 0.025, 0.025, 0.0125, 0.0125, 0.0125, 0.0125])
# binh phuong hoi tu on -> loss ~ 0.0036, binh thuong ~ 0.044
# alpha_fea = np.array([0.5675298404513692, 0.06600188449032131, 0.17457516359798433, 0.12414202360303854, 0.03173022202080037,
#     0.008797713645306052, 0.005725388902748499, 0.014487332613697576, 0.007010430674734028])
# loss ~ 0.0024 (binh phuong), ~ 0.0036 (binh thuong)
alpha_fea = np.array([3.0016, -0.0518,  0.0628,  0.0500, -0.0543, -0.0306,  0.0556, -0.0545,
         0.0543])
alpha_fea = alpha_fea ** 2
alpha_fea = alpha_fea / np.sum(alpha_fea) * len(alpha_fea)
alpha_fea_T = alpha_fea.T
(np.sum(alpha_fea), alpha_fea)
# Out:
# (9.0,
#  array([8.97805508e+00, 2.67384453e-03, 3.93003049e-03, 2.49124615e-03,
#         2.93816575e-03, 9.33081298e-04, 3.08053548e-03, 2.95984955e-03,
#         2.93816575e-03]))

# %%
def distance_fn(x, y):
    if y.ndim == 1 and x.ndim == 1:
        return np.sqrt(np.sum((x - y) ** 2 * alpha_fea))
    elif x.ndim == 2 and y.ndim == 2:
        if x.shape[0] != 1 and x.shape != y.shape:
            raise ValueError("x should have shape (1, n)")
        return np.sqrt(np.dot((x - y) ** 2, alpha_fea_T))
    else:
        raise ValueError("Not support x and v")

# %%
plt.figure(figsize=(25, 15))
plt.subplots_adjust(hspace=0.4, wspace=0.15)

battery_cycle_infos = dataframe[dataframe['battery_order'] == test_battery_orders[0]]\
    [["c1a_I_dt", "c1a_avg_T", "c1a_avg_I", "c1_max_I","c2_max_I", "c1_max_T", "c1_min_T", "c2_max_T", "c2_min_T"]]\
    .to_numpy()

y_test = dataframe[dataframe['battery_order'] == test_battery_orders[i]][["Qi"]].to_numpy()
y_pred = []

for i in range(len(y_test)):
    _X = np.append(train_X, battery_cycle_infos[i], axis=0)
    _Y = np.append((Y[:train_size], np.nan), axis=0)
    _N = len(Y)
    alg = sSMC_FCM(distance_fn=distance_fn)

    # initialize variables; initialize U, V, m2
    print("Initializing variables")
    max_iter = 300
    alpha = 0.5
    alg.X = _X
    alg.Y = _Y
    alg.U = np.zeros((_N, C))
    alg.m = 2
    alg.epsilon = 0.0001
    total_count_time = time.time()
    alg.V = cg.sSMC_FCM_kmean_plus_plus(_X, _Y, C, alg.distance_fn, alg.lnorm)
    total_count_time = time.time() - total_count_time
    print("Initialized cluster centers in ", total_count_time, " s")

    total_count_time = time.time()
    alg.U = alg.update_U_non_supervision()
    total_count_time = time.time() - total_count_time
    print("Update U non_supervision in ", total_count_time, " s")

    total_count_time = time.time()
    alg.m2 = alg.calculate_m2(alpha)
    total_count_time = time.time() - total_count_time
    print("Initialized m2: ", alg.m2, " in ", total_count_time, " s")

    total_count_time = time.time()
    print("Start solving the algorithm")
    for l in range(max_iter):
        count_time = time.time()
        alg.U = alg.update_U()
        U_count_time = time.time() - count_time

        alg.V_old = alg.V

        count_time = time.time()
        alg.V = alg.update_V()
        V_count_time = time.time() - count_time

        print(f"Iteration {l}/{max_iter} completed in {U_count_time + V_count_time} s")
        print(f"U, V calculation time consume: {U_count_time} s, {V_count_time} s")

        if alg.is_converged():
            break
    total_count_time = time.time() - total_count_time
    print(f"Time consuming: {total_count_time} s")

    pred_y = np.argmax(alg.U[-1])
    pred_Qi = clusters_Qi[int(pred_y)]
    y_pred.append(pred_Qi)


cycles = range(0, len(y_test))
print(len(y_test), len(y_pred))
mse = mean_squared_error(y_test, y_pred)

# Plot the results as line plot
# plt.subplot(3, 3, i + 1)
plt.plot(cycles, y_test, label='Actual Qi', color='blue')
plt.plot(cycles, y_pred, label='Predicted Qi', color='red')
plt.xlabel('Cycle')
plt.ylabel('Qi')
plt.ylim(0, 1.5)
plt.title(f'Battery {test_battery_orders[i]} (MSE: {mse})')
plt.show()
# Out:
# Initializing variables
# Initialized cluster centers in  0.19824647903442383  s
# Update U non_supervision in  1.488586664199829  s
# Initialized m2:  18  in  0.11580085754394531  s
# Start solving the algorithm
# Iteration 0/300 completed in 6.606159210205078 s
# U, V calculation time consume: 6.5623509883880615 s, 0.0438082218170166 s
# Iteration 1/300 completed in 5.514224052429199 s
# U, V calculation time consume: 5.470994710922241 s, 0.04322934150695801 s
# Iteration 2/300 completed in 6.4149696826934814 s
# U, V calculation time consume: 6.369237899780273 s, 0.04573178291320801 s
# Iteration 3/300 completed in 5.438220739364624 s
# U, V calculation time consume: 5.392851829528809 s, 0.04536890983581543 s
# Iteration 4/300 completed in 6.5007100105285645 s
# U, V calculation time consume: 6.456104516983032 s, 0.04460549354553223 s
# Iteration 5/300 completed in 5.390535593032837 s
# U, V calculation time consume: 5.344202041625977 s, 0.04633355140686035 s
# Iteration 6/300 completed in 6.445922374725342 s
# U, V calculation time consume: 6.363412857055664 s, 0.08250951766967773 s
# Iteration 7/300 completed in 5.3924384117126465 s
# U, V calculation time consume: 5.339236259460449 s, 0.053202152252197266 s
# Iteration 8/300 completed in 5.764988422393799 s
# U, V calculation time consume: 5.703484058380127 s, 0.061504364013671875 s
# Iteration 9/300 completed in 5.940037488937378 s
# U, V calculation time consume: 5.896178722381592 s, 0.04385876655578613 s
# Iteration 10/300 completed in 5.315614461898804 s
# U, V calculation time consume: 5.268696069717407 s, 0.046918392181396484 s
# Iteration 11/300 completed in 6.569922924041748 s
# U, V calculation time consume: 6.525975704193115 s, 0.04394721984863281 s
# Iteration 12/300 completed in 5.395549774169922 s
# U, V calculation time consume: 5.351040363311768 s, 0.0445094108581543 s
# Iteration 13/300 completed in 6.442649602890015 s
# U, V calculation time consume: 6.399233818054199 s, 0.04341578483581543 s
# Iteration 14/300 completed in 5.356499671936035 s
# U, V calculation time consume: 5.3148109912872314 s, 0.04168868064880371 s
# Iteration 15/300 completed in 6.378589868545532 s
# U, V calculation time consume: 6.333878755569458 s, 0.04471111297607422 s
# Iteration 16/300 completed in 5.428934574127197 s
# U, V calculation time consume: 5.384983062744141 s, 0.04395151138305664 s
# Iteration 17/300 completed in 6.46713924407959 s
# U, V calculation time consume: 6.424114227294922 s, 0.04302501678466797 s
# Iteration 18/300 completed in 5.401687145233154 s
# U, V calculation time consume: 5.350205898284912 s, 0.05148124694824219 s
# Iteration 19/300 completed in 6.362296104431152 s
# U, V calculation time consume: 6.319456338882446 s, 0.042839765548706055 s
# Iteration 20/300 completed in 5.312001466751099 s
# U, V calculation time consume: 5.267557621002197 s, 0.04444384574890137 s
# Iteration 21/300 completed in 6.521681070327759 s
# U, V calculation time consume: 6.478301763534546 s, 0.04337930679321289 s
# Iteration 22/300 completed in 5.406675577163696 s
# U, V calculation time consume: 5.35761284828186 s, 0.04906272888183594 s
# Iteration 23/300 completed in 6.305756330490112 s
# U, V calculation time consume: 6.210589170455933 s, 0.09516716003417969 s
# Iteration 24/300 completed in 5.424575567245483 s
# U, V calculation time consume: 5.379034757614136 s, 0.045540809631347656 s
# Iteration 25/300 completed in 5.893547296524048 s
# U, V calculation time consume: 5.835449934005737 s, 0.05809736251831055 s
# Iteration 26/300 completed in 6.005739450454712 s
# U, V calculation time consume: 5.960857629776001 s, 0.04488182067871094 s
# Iteration 27/300 completed in 5.345600605010986 s
# U, V calculation time consume: 5.3019702434539795 s, 0.043630361557006836 s
# Iteration 28/300 completed in 6.3720386028289795 s
# U, V calculation time consume: 6.327810764312744 s, 0.04422783851623535 s
# Iteration 29/300 completed in 5.4037559032440186 s
# U, V calculation time consume: 5.361898899078369 s, 0.041857004165649414 s
# Iteration 30/300 completed in 6.411983489990234 s
# U, V calculation time consume: 6.352809429168701 s, 0.0591740608215332 s
# Iteration 31/300 completed in 5.449206352233887 s
# U, V calculation time consume: 5.406386613845825 s, 0.04281973838806152 s
# Iteration 32/300 completed in 6.739423990249634 s
# U, V calculation time consume: 6.6961822509765625 s, 0.04324173927307129 s
# Iteration 33/300 completed in 5.456180095672607 s
# U, V calculation time consume: 5.412897825241089 s, 0.043282270431518555 s
# Iteration 34/300 completed in 6.551701545715332 s
# U, V calculation time consume: 6.50684118270874 s, 0.0448603630065918 s
# Iteration 35/300 completed in 5.417623996734619 s
# U, V calculation time consume: 5.374260425567627 s, 0.04336357116699219 s
# Iteration 36/300 completed in 6.4544456005096436 s
# U, V calculation time consume: 6.413168430328369 s, 0.041277170181274414 s
# Iteration 37/300 completed in 5.350736379623413 s
# U, V calculation time consume: 5.306793212890625 s, 0.043943166732788086 s
# Iteration 38/300 completed in 6.518153667449951 s
# U, V calculation time consume: 6.472637176513672 s, 0.0455164909362793 s
# Iteration 39/300 completed in 5.473758935928345 s
# U, V calculation time consume: 5.43107795715332 s, 0.042680978775024414 s
# Iteration 40/300 completed in 6.505074501037598 s
# U, V calculation time consume: 6.4573564529418945 s, 0.047718048095703125 s
# Iteration 41/300 completed in 5.292654037475586 s
# U, V calculation time consume: 5.236120700836182 s, 0.0565333366394043 s
# Iteration 42/300 completed in 6.029707670211792 s
# U, V calculation time consume: 5.932271957397461 s, 0.09743571281433105 s
# Iteration 43/300 completed in 5.733727693557739 s
# U, V calculation time consume: 5.6880104541778564 s, 0.04571723937988281 s
# Iteration 44/300 completed in 5.347717046737671 s
# U, V calculation time consume: 5.299925804138184 s, 0.047791242599487305 s
# Iteration 45/300 completed in 6.182410478591919 s
# U, V calculation time consume: 6.1388304233551025 s, 0.043580055236816406 s
# Iteration 46/300 completed in 5.5155768394470215 s
# U, V calculation time consume: 5.4739391803741455 s, 0.04163765907287598 s
# Iteration 47/300 completed in 6.412008285522461 s
# U, V calculation time consume: 6.369716167449951 s, 0.042292118072509766 s
# Iteration 48/300 completed in 5.428028583526611 s
# U, V calculation time consume: 5.387479782104492 s, 0.04054880142211914 s
# Iteration 49/300 completed in 6.707310199737549 s
# U, V calculation time consume: 6.662168979644775 s, 0.04514122009277344 s
# Iteration 50/300 completed in 5.500355005264282 s
# U, V calculation time consume: 5.458520174026489 s, 0.04183483123779297 s
# Iteration 51/300 completed in 6.426406145095825 s
# U, V calculation time consume: 6.383585214614868 s, 0.04282093048095703 s
# Iteration 52/300 completed in 5.535436153411865 s
# U, V calculation time consume: 5.492016315460205 s, 0.043419837951660156 s
# Iteration 53/300 completed in 6.403811454772949 s
# U, V calculation time consume: 6.362453460693359 s, 0.041357994079589844 s
# Iteration 54/300 completed in 5.414234399795532 s
# U, V calculation time consume: 5.372483253479004 s, 0.04175114631652832 s
# Iteration 55/300 completed in 6.582427501678467 s
# U, V calculation time consume: 6.52646541595459 s, 0.05596208572387695 s
# Iteration 56/300 completed in 5.488168001174927 s
# U, V calculation time consume: 5.442044496536255 s, 0.046123504638671875 s
# Iteration 57/300 completed in 6.531978607177734 s
# U, V calculation time consume: 6.489878416061401 s, 0.04210019111633301 s
# Iteration 58/300 completed in 5.353052616119385 s
# U, V calculation time consume: 5.309499740600586 s, 0.04355287551879883 s
# Iteration 59/300 completed in 6.592806100845337 s
# U, V calculation time consume: 6.547505855560303 s, 0.04530024528503418 s
# Iteration 60/300 completed in 5.525551795959473 s
# U, V calculation time consume: 5.473443984985352 s, 0.052107810974121094 s
# Iteration 61/300 completed in 6.733454465866089 s
# U, V calculation time consume: 6.670367479324341 s, 0.06308698654174805 s
# Iteration 62/300 completed in 5.548706531524658 s
# U, V calculation time consume: 5.505158185958862 s, 0.0435483455657959 s
# Iteration 63/300 completed in 6.053665637969971 s
# U, V calculation time consume: 5.976360559463501 s, 0.07730507850646973 s
# Iteration 64/300 completed in 5.999884366989136 s
# U, V calculation time consume: 5.957568168640137 s, 0.04231619834899902 s
# Iteration 65/300 completed in 5.776308536529541 s
# U, V calculation time consume: 5.719144582748413 s, 0.05716395378112793 s
# Iteration 66/300 completed in 6.221345663070679 s
# U, V calculation time consume: 6.176607370376587 s, 0.0447382926940918 s
# Iteration 67/300 completed in 5.430056571960449 s
# U, V calculation time consume: 5.385735273361206 s, 0.044321298599243164 s
# Iteration 68/300 completed in 6.631052255630493 s
# U, V calculation time consume: 6.587829113006592 s, 0.04322314262390137 s
# Iteration 69/300 completed in 5.5562121868133545 s
# U, V calculation time consume: 5.512343645095825 s, 0.0438685417175293 s
# Iteration 70/300 completed in 6.596801519393921 s
# U, V calculation time consume: 6.549878835678101 s, 0.04692268371582031 s
# Iteration 71/300 completed in 5.806280612945557 s
# U, V calculation time consume: 5.761616945266724 s, 0.04466366767883301 s
# Iteration 72/300 completed in 6.659813165664673 s
# U, V calculation time consume: 6.615246057510376 s, 0.044567108154296875 s
# Iteration 73/300 completed in 5.632336139678955 s
# U, V calculation time consume: 5.591307878494263 s, 0.04102826118469238 s
# Iteration 74/300 completed in 6.575235366821289 s
# U, V calculation time consume: 6.526951789855957 s, 0.04828357696533203 s
# Iteration 75/300 completed in 5.719845771789551 s
# U, V calculation time consume: 5.67559027671814 s, 0.04425549507141113 s
# Iteration 76/300 completed in 6.6213648319244385 s
# U, V calculation time consume: 6.576094150543213 s, 0.045270681381225586 s
# Iteration 77/300 completed in 5.782341480255127 s
# U, V calculation time consume: 5.737564563751221 s, 0.04477691650390625 s
# Iteration 78/300 completed in 6.576929807662964 s
# U, V calculation time consume: 6.532595634460449 s, 0.04433417320251465 s
# Iteration 79/300 completed in 5.734520196914673 s
# U, V calculation time consume: 5.683712959289551 s, 0.05080723762512207 s
# Iteration 80/300 completed in 6.610574245452881 s
# U, V calculation time consume: 6.557427883148193 s, 0.0531463623046875 s
# Iteration 81/300 completed in 5.689205646514893 s
# U, V calculation time consume: 5.632308721542358 s, 0.05689692497253418 s
# Iteration 82/300 completed in 6.525777101516724 s
# U, V calculation time consume: 6.476328372955322 s, 0.04944872856140137 s
# Iteration 83/300 completed in 5.685530662536621 s
# U, V calculation time consume: 5.642816066741943 s, 0.042714595794677734 s
# Iteration 84/300 completed in 6.644805669784546 s
# U, V calculation time consume: 6.600406646728516 s, 0.04439902305603027 s
# Iteration 85/300 completed in 5.627197742462158 s
# U, V calculation time consume: 5.584160804748535 s, 0.04303693771362305 s
# Iteration 86/300 completed in 6.644553184509277 s
# U, V calculation time consume: 6.596577167510986 s, 0.047976016998291016 s
# Iteration 87/300 completed in 5.8907763957977295 s
# U, V calculation time consume: 5.845844030380249 s, 0.04493236541748047 s
# Iteration 88/300 completed in 6.592017650604248 s
# U, V calculation time consume: 6.5474114418029785 s, 0.04460620880126953 s
# Iteration 89/300 completed in 5.711054801940918 s
# U, V calculation time consume: 5.66899847984314 s, 0.04205632209777832 s
# Iteration 90/300 completed in 6.559163808822632 s
# U, V calculation time consume: 6.510392427444458 s, 0.04877138137817383 s
# Iteration 91/300 completed in 5.701685190200806 s
# U, V calculation time consume: 5.651662111282349 s, 0.05002307891845703 s
# Iteration 92/300 completed in 6.593181371688843 s
# U, V calculation time consume: 6.5493528842926025 s, 0.043828487396240234 s
# Iteration 93/300 completed in 5.53397798538208 s
# U, V calculation time consume: 5.486817121505737 s, 0.04716086387634277 s
# Iteration 94/300 completed in 6.58980655670166 s
# U, V calculation time consume: 6.545523405075073 s, 0.044283151626586914 s
# Iteration 95/300 completed in 5.494220972061157 s
# U, V calculation time consume: 5.444177150726318 s, 0.05004382133483887 s
# Iteration 96/300 completed in 6.592413902282715 s
# U, V calculation time consume: 6.546433687210083 s, 0.045980215072631836 s
# Iteration 97/300 completed in 5.4420082569122314 s
# U, V calculation time consume: 5.399109601974487 s, 0.04289865493774414 s
# Iteration 98/300 completed in 6.35614275932312 s
# U, V calculation time consume: 6.314292669296265 s, 0.04185009002685547 s
# Iteration 99/300 completed in 5.442296981811523 s
# U, V calculation time consume: 5.400551795959473 s, 0.04174518585205078 s
# Iteration 100/300 completed in 6.223998069763184 s
# U, V calculation time consume: 6.182318687438965 s, 0.04167938232421875 s
# Iteration 101/300 completed in 5.366919755935669 s
# U, V calculation time consume: 5.320222616195679 s, 0.046697139739990234 s
# Iteration 102/300 completed in 6.321928262710571 s
# U, V calculation time consume: 6.27916407585144 s, 0.04276418685913086 s
# Iteration 103/300 completed in 5.404876708984375 s
# U, V calculation time consume: 5.339169979095459 s, 0.06570672988891602 s
# Iteration 104/300 completed in 6.242126226425171 s
# U, V calculation time consume: 6.189327239990234 s, 0.05279898643493652 s
# Iteration 105/300 completed in 5.350376129150391 s
# U, V calculation time consume: 5.305906295776367 s, 0.04446983337402344 s
# Iteration 106/300 completed in 6.301912546157837 s
# U, V calculation time consume: 6.259718656539917 s, 0.04219388961791992 s
# Iteration 107/300 completed in 5.409140586853027 s
# U, V calculation time consume: 5.364765405654907 s, 0.04437518119812012 s
# Iteration 108/300 completed in 6.262909889221191 s
# U, V calculation time consume: 6.219794273376465 s, 0.04311561584472656 s
# Iteration 109/300 completed in 5.37165904045105 s
# U, V calculation time consume: 5.327675819396973 s, 0.04398322105407715 s
# Iteration 110/300 completed in 6.11081600189209 s
# U, V calculation time consume: 6.050042390823364 s, 0.060773611068725586 s
# Iteration 111/300 completed in 5.350822448730469 s
# U, V calculation time consume: 5.307540655136108 s, 0.04328179359436035 s
# Iteration 112/300 completed in 5.5608508586883545 s
# U, V calculation time consume: 5.470719337463379 s, 0.09013152122497559 s
# Iteration 113/300 completed in 5.991612195968628 s
# U, V calculation time consume: 5.948558568954468 s, 0.043053627014160156 s
# Iteration 114/300 completed in 5.266972780227661 s
# U, V calculation time consume: 5.224870443344116 s, 0.04210233688354492 s
# Iteration 115/300 completed in 6.180235147476196 s
# U, V calculation time consume: 6.137043476104736 s, 0.04319167137145996 s
# Iteration 116/300 completed in 5.329823732376099 s
# U, V calculation time consume: 5.288304805755615 s, 0.0415189266204834 s
# Iteration 117/300 completed in 6.223158121109009 s
# U, V calculation time consume: 6.180258512496948 s, 0.04289960861206055 s
# Iteration 118/300 completed in 5.331524848937988 s
# U, V calculation time consume: 5.288824081420898 s, 0.042700767517089844 s
# Iteration 119/300 completed in 6.229737758636475 s
# U, V calculation time consume: 6.185903310775757 s, 0.04383444786071777 s
# Iteration 120/300 completed in 5.2906577587127686 s
# U, V calculation time consume: 5.2473108768463135 s, 0.04334688186645508 s
# Iteration 121/300 completed in 6.230393409729004 s
# U, V calculation time consume: 6.186865329742432 s, 0.043528079986572266 s
# Iteration 122/300 completed in 5.294405698776245 s
# U, V calculation time consume: 5.2516703605651855 s, 0.04273533821105957 s
# Iteration 123/300 completed in 6.279836177825928 s
# U, V calculation time consume: 6.235271453857422 s, 0.04456472396850586 s
# Iteration 124/300 completed in 5.167993545532227 s
# U, V calculation time consume: 5.124923229217529 s, 0.043070316314697266 s
# Iteration 125/300 completed in 6.122926950454712 s
# U, V calculation time consume: 6.078712224960327 s, 0.044214725494384766 s
# Iteration 126/300 completed in 5.348545789718628 s
# U, V calculation time consume: 5.306509017944336 s, 0.04203677177429199 s
# Iteration 127/300 completed in 5.845099925994873 s
# U, V calculation time consume: 5.755611896514893 s, 0.08948802947998047 s
# Iteration 128/300 completed in 5.581439971923828 s
# U, V calculation time consume: 5.538821697235107 s, 0.0426182746887207 s
# Iteration 129/300 completed in 5.1766674518585205 s
# U, V calculation time consume: 5.132601499557495 s, 0.04406595230102539 s
# Iteration 130/300 completed in 6.203706979751587 s
# U, V calculation time consume: 6.162199974060059 s, 0.04150700569152832 s
# Iteration 131/300 completed in 5.237321615219116 s
# U, V calculation time consume: 5.194459438323975 s, 0.0428621768951416 s
# Iteration 132/300 completed in 6.173705339431763 s
# U, V calculation time consume: 6.13275933265686 s, 0.040946006774902344 s
# Iteration 133/300 completed in 5.285962820053101 s
# U, V calculation time consume: 5.2417309284210205 s, 0.04423189163208008 s
# Iteration 134/300 completed in 6.242827892303467 s
# U, V calculation time consume: 6.199835300445557 s, 0.042992591857910156 s
# Iteration 135/300 completed in 5.264171361923218 s
# U, V calculation time consume: 5.2182159423828125 s, 0.04595541954040527 s
# Iteration 136/300 completed in 6.248904466629028 s
# U, V calculation time consume: 6.204784154891968 s, 0.04412031173706055 s
# Iteration 137/300 completed in 5.317150592803955 s
# U, V calculation time consume: 5.274406433105469 s, 0.04274415969848633 s
# Iteration 138/300 completed in 6.35280442237854 s
# U, V calculation time consume: 6.311320781707764 s, 0.04148364067077637 s
# Iteration 139/300 completed in 5.302731990814209 s
# U, V calculation time consume: 5.260395288467407 s, 0.04233670234680176 s
# Iteration 140/300 completed in 6.20808219909668 s
# U, V calculation time consume: 6.165467977523804 s, 0.04261422157287598 s
# Iteration 141/300 completed in 5.200152158737183 s
# U, V calculation time consume: 5.155251502990723 s, 0.04490065574645996 s
# Iteration 142/300 completed in 5.814793825149536 s
# U, V calculation time consume: 5.763884782791138 s, 0.05090904235839844 s
# Iteration 143/300 completed in 5.698747396469116 s
# U, V calculation time consume: 5.65444803237915 s, 0.04429936408996582 s
# Iteration 144/300 completed in 5.578177452087402 s
# U, V calculation time consume: 5.492161273956299 s, 0.08601617813110352 s
# Iteration 145/300 completed in 6.594706058502197 s
# U, V calculation time consume: 6.541285991668701 s, 0.053420066833496094 s
# Iteration 146/300 completed in 6.130036115646362 s
# U, V calculation time consume: 6.044598340988159 s, 0.08543777465820312 s
# Iteration 147/300 completed in 6.499036073684692 s
# U, V calculation time consume: 6.432655334472656 s, 0.06638073921203613 s
# Iteration 148/300 completed in 6.034989356994629 s
# U, V calculation time consume: 5.938999891281128 s, 0.09598946571350098 s
# Iteration 149/300 completed in 5.818950891494751 s
# U, V calculation time consume: 5.77427077293396 s, 0.044680118560791016 s
# Iteration 150/300 completed in 5.3256189823150635 s
# U, V calculation time consume: 5.281261444091797 s, 0.0443575382232666 s
# Iteration 151/300 completed in 6.272926092147827 s
# U, V calculation time consume: 6.228163957595825 s, 0.04476213455200195 s
# Iteration 152/300 completed in 5.316941738128662 s
# U, V calculation time consume: 5.271736145019531 s, 0.04520559310913086 s
# Iteration 153/300 completed in 6.213233232498169 s
# U, V calculation time consume: 6.166983127593994 s, 0.046250104904174805 s
# Iteration 154/300 completed in 5.255749940872192 s
# U, V calculation time consume: 5.21306037902832 s, 0.04268956184387207 s
# Iteration 155/300 completed in 6.248899459838867 s
# U, V calculation time consume: 6.204191207885742 s, 0.044708251953125 s
# Iteration 156/300 completed in 5.474384546279907 s
# U, V calculation time consume: 5.429348468780518 s, 0.04503607749938965 s
# Iteration 157/300 completed in 6.2265660762786865 s
# U, V calculation time consume: 6.179455280303955 s, 0.047110795974731445 s
# Iteration 158/300 completed in 5.300931215286255 s
# U, V calculation time consume: 5.256181716918945 s, 0.04474949836730957 s
# Iteration 159/300 completed in 6.329540014266968 s
# U, V calculation time consume: 6.284285068511963 s, 0.04525494575500488 s
# Iteration 160/300 completed in 5.245927333831787 s
# U, V calculation time consume: 5.203240633010864 s, 0.04268670082092285 s
# Iteration 161/300 completed in 6.277344465255737 s
# U, V calculation time consume: 6.231991767883301 s, 0.04535269737243652 s
# Iteration 162/300 completed in 5.281566381454468 s
# U, V calculation time consume: 5.237201452255249 s, 0.04436492919921875 s
# Iteration 163/300 completed in 6.084449529647827 s
# U, V calculation time consume: 6.009042501449585 s, 0.07540702819824219 s
# Iteration 164/300 completed in 5.49450159072876 s
# U, V calculation time consume: 5.444105863571167 s, 0.05039572715759277 s
# Iteration 165/300 completed in 5.637643337249756 s
# U, V calculation time consume: 5.544483184814453 s, 0.09316015243530273 s
# Iteration 166/300 completed in 5.9403395652771 s
# U, V calculation time consume: 5.894283056259155 s, 0.046056509017944336 s
# Iteration 167/300 completed in 5.213927745819092 s
# U, V calculation time consume: 5.1676695346832275 s, 0.04625821113586426 s
# Iteration 168/300 completed in 6.193305492401123 s
# U, V calculation time consume: 6.147840976715088 s, 0.045464515686035156 s
# Iteration 169/300 completed in 5.295232772827148 s
# U, V calculation time consume: 5.248854637145996 s, 0.046378135681152344 s
# Iteration 170/300 completed in 6.243907690048218 s
# U, V calculation time consume: 6.199630975723267 s, 0.04427671432495117 s
# Iteration 171/300 completed in 5.274472713470459 s
# U, V calculation time consume: 5.229516506195068 s, 0.044956207275390625 s
# Iteration 172/300 completed in 6.3245158195495605 s
# U, V calculation time consume: 6.2792558670043945 s, 0.045259952545166016 s
# Iteration 173/300 completed in 5.475687742233276 s
# U, V calculation time consume: 5.422267198562622 s, 0.0534205436706543 s
# Iteration 174/300 completed in 6.0897932052612305 s
# U, V calculation time consume: 6.046970367431641 s, 0.042822837829589844 s
# Iteration 175/300 completed in 5.207930326461792 s
# U, V calculation time consume: 5.164278030395508 s, 0.04365229606628418 s
# Iteration 176/300 completed in 6.124569892883301 s
# U, V calculation time consume: 6.0833213329315186 s, 0.04124855995178223 s
# Iteration 177/300 completed in 5.297313213348389 s
# U, V calculation time consume: 5.251793384552002 s, 0.04551982879638672 s
# Iteration 178/300 completed in 6.24328088760376 s
# U, V calculation time consume: 6.192753076553345 s, 0.05052781105041504 s
# Iteration 179/300 completed in 5.257779836654663 s
# U, V calculation time consume: 5.212655067443848 s, 0.04512476921081543 s
# Iteration 180/300 completed in 5.717865943908691 s
# U, V calculation time consume: 5.6306562423706055 s, 0.08720970153808594 s
# Iteration 181/300 completed in 5.682132244110107 s
# U, V calculation time consume: 5.638671636581421 s, 0.04346060752868652 s
# Iteration 182/300 completed in 5.272998571395874 s
# U, V calculation time consume: 5.227701425552368 s, 0.04529714584350586 s
# Iteration 183/300 completed in 6.301145792007446 s
# U, V calculation time consume: 6.256782054901123 s, 0.04436373710632324 s
# Iteration 184/300 completed in 5.376848220825195 s
# U, V calculation time consume: 5.332454204559326 s, 0.04439401626586914 s
# Iteration 185/300 completed in 6.18734884262085 s
# U, V calculation time consume: 6.143046617507935 s, 0.04430222511291504 s
# Iteration 186/300 completed in 5.400130033493042 s
# U, V calculation time consume: 5.353438377380371 s, 0.0466916561126709 s
# Iteration 187/300 completed in 6.213032007217407 s
# U, V calculation time consume: 6.170246362686157 s, 0.04278564453125 s
# Iteration 188/300 completed in 5.3221824169158936 s
# U, V calculation time consume: 5.278509140014648 s, 0.04367327690124512 s
# Iteration 189/300 completed in 6.2698657512664795 s
# U, V calculation time consume: 6.225864887237549 s, 0.044000864028930664 s
# Iteration 190/300 completed in 5.339826583862305 s
# U, V calculation time consume: 5.298140048980713 s, 0.0416865348815918 s
# Iteration 191/300 completed in 6.275918960571289 s
# U, V calculation time consume: 6.234626293182373 s, 0.041292667388916016 s
# Iteration 192/300 completed in 5.249855041503906 s
# U, V calculation time consume: 5.206548452377319 s, 0.043306589126586914 s
# Iteration 193/300 completed in 6.207258701324463 s
# U, V calculation time consume: 6.163685083389282 s, 0.043573617935180664 s
# Iteration 194/300 completed in 5.333409786224365 s
# U, V calculation time consume: 5.292381048202515 s, 0.041028738021850586 s
# Iteration 195/300 completed in 6.191762447357178 s
# U, V calculation time consume: 6.1477439403533936 s, 0.04401850700378418 s
# Iteration 196/300 completed in 5.301453351974487 s
# U, V calculation time consume: 5.25777792930603 s, 0.04367542266845703 s
# Iteration 197/300 completed in 5.72797155380249 s
# U, V calculation time consume: 5.667842864990234 s, 0.06012868881225586 s
# Iteration 198/300 completed in 5.817304849624634 s
# U, V calculation time consume: 5.775137186050415 s, 0.04216766357421875 s
# Iteration 199/300 completed in 5.3277082443237305 s
# U, V calculation time consume: 5.2847723960876465 s, 0.042935848236083984 s
# Iteration 200/300 completed in 6.171786546707153 s
# U, V calculation time consume: 6.127434253692627 s, 0.04435229301452637 s
# Iteration 201/300 completed in 5.338006019592285 s
# U, V calculation time consume: 5.294079303741455 s, 0.04392671585083008 s
# Time consuming: 1186.3608767986298 s

# %%
pred_y = np.argmax(alg.U, axis=1)

mse_loss = 0
for i in range(N):
    cluster_index = pred_y[i]
    mse_loss += (clusters_Qi[cluster_index] - elements_Qi[i]) ** 2

print("loss", mse_loss/N)
# Out:
# loss [0.00029009]

# %%
Y[train_size:]
# Out:
# array([nan, nan, nan, ..., nan, nan, nan])

# %%
pred_Qi = np.array([clusters_Qi[pred_y[i]] for i in range(train_size, N)])
# pred_Qi = np.zeros(test_size)
# for i in range(test_size):
#     idx = i + train_size
#     u = alg.U[i] ** 2
#     pred_Qi[i] = np.sum(u * clusters_Qi)
print("MSE Test loss: ", mean_squared_error(elements_Qi[train_size:], pred_Qi))
# Out:
# MSE Test loss:  0.0020529885921035207

# %%
from sklearn.metrics import accuracy_score
(accuracy_score(Y[:train_size], pred_y[:train_size]), accuracy_score(test_Y, pred_y[train_size:]))
# Out:
# (0.9941098260111227, 0.1563879789203817)

# %%
pred_column = np.zeros((len(dataframe), 1))

test_dataindexes = dataframe[dataframe['battery_order'].isin(test_battery_orders)]\
      [['battery_order', 'cycle_order']].to_numpy()

# %%
plt.figure(figsize=(25, 15))
plt.subplots_adjust(hspace=0.4, wspace=0.15)

for i in range(0, 9):
    y_test = dataframe[dataframe['battery_order'] == test_battery_orders[i]][["Qi"]]
    y_test = y_test.to_numpy()
    cycles = range(0, len(y_test))
    s_idx = np.where(test_dataindexes[:, 0] == test_battery_orders[i])[0][0]
    print(s_idx)
    e_idx = s_idx + battery_cycles_count[test_battery_orders[i] - 1]
    print(s_idx, e_idx)
    y_pred = pred_Qi[s_idx:e_idx]
    print(len(y_test), len(y_pred))
    mse = mean_squared_error(y_test, y_pred)

    # Save predictions
    from_index = dataframe[dataframe['battery_order'] == test_battery_orders[i]].index[0]
    to_index = dataframe[dataframe['battery_order'] == test_battery_orders[i]].index[-1]
    pred_column[from_index:to_index + 1] = y_pred.reshape(-1, 1)

    # Plot the results as line plot
    plt.subplot(3, 3, i + 1)
    plt.plot(cycles, y_test, label='Actual Qi', color='blue')
    plt.plot(cycles, y_pred, label='Predicted Qi', color='red')
    plt.xlabel('Cycle')
    plt.ylabel('Qi')
    plt.ylim(0, 1.5)
    plt.title(f'Battery {test_battery_orders[i]} (MSE: {mse})')


plt.suptitle('sSMC FCM Predictions')
# Out:
# 6051
# 6051 6537
# 486 486
# 2287
# 2287 3073
# 786 786
# 0
# 0 1432
# 1432 1432
# 6537
# 6537 7021
# 484 484
# 5087
# 5087 6051
# 964 964
# 4385
# 4385 5087
# 702 702
# 3630
# 3630 4385
# 755 755
# 3073
# 3073 3630
# 557 557
# 1432
# 1432 2287
# 855 855
# Text(0.5, 0.98, 'sSMC FCM Predictions')

# %%
pred_but_true_Qi = np.array([clusters_Qi[int(test_Y[i])] for i in range(test_size)])

plt.figure(figsize=(25, 15))
plt.subplots_adjust(hspace=0.4, wspace=0.15)

for i in range(0, 9):
    y_test = dataframe[dataframe['battery_order'] == test_battery_orders[i]][["Qi"]]
    y_test = y_test.to_numpy()
    cycles = range(0, len(y_test))
    s_idx = np.where(test_dataindexes[:, 0] == test_battery_orders[i])[0][0]
    print(s_idx)
    e_idx = s_idx + battery_cycles_count[test_battery_orders[i] - 1]
    print(s_idx, e_idx)
    y_pred = pred_but_true_Qi[s_idx:e_idx]
    print(len(y_test), len(y_pred))
    mse = mean_squared_error(y_test, y_pred)

    # Save predictions
    from_index = dataframe[dataframe['battery_order'] == test_battery_orders[i]].index[0]
    to_index = dataframe[dataframe['battery_order'] == test_battery_orders[i]].index[-1]
    pred_column[from_index:to_index + 1] = y_pred.reshape(-1, 1)

    # Plot the results as line plot
    plt.subplot(3, 3, i + 1)
    plt.plot(cycles, y_test, label='Actual Qi', color='blue')
    plt.plot(cycles, y_pred, label='Predicted Qi', color='red')
    plt.xlabel('Cycle')
    plt.ylabel('Qi')
    plt.ylim(0, 1.5)
    plt.title(f'Battery {test_battery_orders[i]} (MSE: {mse})')


plt.suptitle('sSMC FCM Predictions')
# Out:
# 6051
# 6051 6537
# 486 486
# 2287
# 2287 3073
# 786 786
# 0
# 0 1432
# 1432 1432
# 6537
# 6537 7021
# 484 484
# 5087
# 5087 6051
# 964 964
# 4385
# 4385 5087
# 702 702
# 3630
# 3630 4385
# 755 755
# 3073
# 3073 3630
# 557 557
# 1432
# 1432 2287
# 855 855
# Text(0.5, 0.98, 'sSMC FCM Predictions')
